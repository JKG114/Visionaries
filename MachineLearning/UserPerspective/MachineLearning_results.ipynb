# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import plot
import matplotlib
import matplotlib.figure
from scipy import stats

df = pd.read_csv('winter_hourly_predictions_519_svm.csv')
# print(df.columns)
true = df['true value'].iloc[:745]
predicted = df['prediction'].iloc[:745]

fig = plt.figure()
fig = plt.figure(figsize=(18,18))
ax = fig.add_subplot(1,1,1)
ax.plot(true, label = 'true values')
ax.plot(predicted, label = 'predicted values ')
# ticks = ax.set_xticks(y1.index)
# ax.set_ylabel('Number of bike rides')
# ax.set_title('Outgoing bike prediction for the most popular station using SVM')
ax.legend(loc = 'best')
plt.show()

# %%
# WINTER: OUTGOING BIKES PREDICTION FOR THE MOST POPULAR STATION

df = pd.read_csv('winter_hourly_predictions_519_reg.csv')
# print(df.columns)
true = df['true value']
predicted = df['prediction']
print(mean_absolute_error(true, predicted))
print(stats.spearmanr(true, predicted))
print(scipy.stats.pearsonr(true, predicted))

df = pd.read_csv('winter_hourly_predictions_519_svm.csv')
# print(df.columns)
true = df['true value']
predicted = df['prediction']
print(mean_absolute_error(true, predicted))
print(stats.spearmanr(true, predicted))
print(scipy.stats.pearsonr(true, predicted))

from sklearn.metrics import mean_absolute_error
df = pd.read_csv('winter_hourly_predictions_519_tree.csv')
# print(df.columns)
true = df['true value']
predicted = df['prediction']
print(mean_absolute_error(true, predicted))
print(stats.spearmanr(true, predicted))
print(scipy.stats.pearsonr(true, predicted))
# Out:
# 5.57014559741
# SpearmanrResult(correlation=0.74181183498544812, pvalue=0.0)
# (0.8537309333566071, 0.0)

# %%
from sklearn.metrics import mean_absolute_error
df = pd.read_csv('winter_hourly_predictions_519_tree.csv')
# print(df.columns)
true = df['true value']
predicted = df['prediction']
print(true.mean())
print(predicted.mean())
print(mean_absolute_error(true, predicted))
print(stats.spearmanr(true, predicted))
print(scipy.stats.pearsonr(true, predicted))
# Out:
# 10.700575815738963
# 11.225070923704427
# 5.05699344482
# SpearmanrResult(correlation=0.80398890052246297, pvalue=0.0)
# (0.8448658372722595, 0.0)

# %%
# WINTER:  OUTGOING BIKES PREDICTION FOR ALL STATIONS

from scipy import stats
import scipy.integrate

df = pd.read_csv('winter_hourly_predictions_lineer_incoming.csv')
true = df['true value']
predicted = df['prediction']
print(stats.spearmanr(true, predicted))
print(scipy.stats.pearsonr(true, predicted))

df = pd.read_csv('winter_hourly_predictions_tree_incoming.csv')
true = df['true value']
predicted = df['prediction']
print(stats.spearmanr(true, predicted))
print(scipy.stats.pearsonr(true,predicted))

df = pd.read_csv('winter_hourly_predictions_svm_incoming.csv')
true = df['true value']
predicted = df['prediction']
print(predicted.mean())
print(stats.spearmanr(true, predicted))
print(scipy.stats.pearsonr(true, predicted))
#
# Out:
# SpearmanrResult(correlation=0.95027933902376027, pvalue=0.0)
# (0.95323041166023481, 0.0)
# SpearmanrResult(correlation=0.97103517553263008, pvalue=0.0)
# (0.92569550339093098, 0.0)
# 778.7202084995198
# SpearmanrResult(correlation=0.93302527743810426, pvalue=0.0)
# (0.89574411955233191, 0.0)
